# %% [markdown]
# # satcom-fec-trust-lab metrics
#
# This notebook is a placeholder for plotting:
#
# - Throughput vs mode (NEON vs SME2)
# - Energy per bit over time
# - Trust score timeline
#
# Populate this with your own CSV or JSON exports from the app and helper scripts.
